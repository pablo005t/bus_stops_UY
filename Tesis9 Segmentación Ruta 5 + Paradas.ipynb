# %%
import geopandas as gpd
from google.colab import drive
drive.mount('/content/drive')

shp_path =  '/content/drive/MyDrive/Tesis/Datos/v_camineria_nacional.shp'
roads = gpd.read_file(shp_path)

print(roads.columns)
print(roads.crs, roads.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Index(['gid', 'codigo', 'numero', 'nombre', 'depto', 'jurisdicci', 'categoria',
#        'sentido', 'carriles', 'calzada', 'fuente', 'observacio', 'nat_juridi',
#        'geometry'],
#       dtype='object')
# EPSG:4326        gid     codigo  numero                        nombre depto  \
# 0  3344250  UY0110000    11.0         José Batlle y Ordoñez  UYCA
# 1   349731  UY0110000    11.0         José Batlle y Ordoñez  UYCA
# 2   292738  UY0270000    27.0                   Mario Heber  UYRV
# 3   305834  UY0050000     5.0  Brig. Gral. Fructuoso Rivera  UYMO
# 4  3343102   UYTA0284     NaN                          None  UYTA
#
#     jurisdicci                categoria  \
# 0     NACIONAL   CORREDOR INTERNACIONAL
# 1     NACIONAL   CORREDOR INTERNACIONAL
# 2     NACIONAL          RUTA SECUNDARIA
# 3     NACIONAL   CORREDOR INTERNACIONAL
# 4  SIN DEFINIR  CAMINERÍA DEPARTAMENTAL
#
#                                              sentido carriles        calzada  \
# 0  EL SENTIDO DE CIRCULACIÓN COINCIDE CON EL DE D...        1  SE VE CALZADA
# 1                      CIRCULACIÓN EN AMBOS SENTIDOS        2  SE VE CALZADA
# 2                      CIRCULACIÓN EN AMBOS SENTIDOS        2  SE VE CALZADA
# 3  EL SENTIDO DE CIRCULACIÓN COINCIDE CON EL DE D...        2  SE VE CALZADA
# 4                      CIRCULACIÓN EN AMBOS SENTIDOS       99   SE VE HUELLA
#
#   fuente observacio nat_juridi  \
# 0    VFN       7-11       None
# 1    VFN       None       None
# 2    VFN       None       None
# 3    VFN       None       None
# 4    VFN       None       None
#
#                                             geometry
# 0  LINESTRING (-55.87298 -34.54738, -55.87303 -34...
# 1  LINESTRING (-56.0249 -34.51454, -56.02669 -34....
# 2  LINESTRING (-55.49775 -31.0364, -55.47293 -31....
# 3  LINESTRING (-56.27475 -34.78458, -56.27479 -34...
# 4  LINESTRING (-55.88549 -31.79666, -55.88545 -31...

# %%
# Filter the GeoDataFrame for route 8
route_5 = roads[roads['numero'] == 5]

# Display the geometry (coordinates) of route 8
print("Coordinates of Route 5:")
display(route_5.geometry)
# Out:
# Coordinates of Route 8:
# 3        LINESTRING (-56.27475 -34.78458, -56.27479 -34...
# 6        LINESTRING (-56.26215 -34.59394, -56.26218 -34...
# 10       LINESTRING (-56.46557 -33.05608, -56.46508 -33...
# 11       LINESTRING (-56.25983 -34.61428, -56.26012 -34...
# 13       LINESTRING (-56.24243 -34.6461, -56.2426 -34.6...
#                                ...
# 39478    LINESTRING (-56.19838 -34.09464, -56.19836 -34...
# 39479    LINESTRING (-56.19743 -34.09574, -56.1975 -34....
# 39484    LINESTRING (-56.19717 -34.09614, -56.19724 -34...
# 39485    LINESTRING (-56.19773 -34.09548, -56.19761 -34...
# 39797    LINESTRING (-56.27033 -34.77391, -56.26925 -34...
# Name: geometry, Length: 702, dtype: geometry

# %%
""" Funcion para llamar la API de maps y descargar la imagen satelital
import requests, time, os

API_KEY = "AIzaSyBhy_zNaeNjqviNw04nfY68hlyYOUBYe4Q"  # <-- reemplazá

session = requests.Session()

def test_static_maps_key(lat, lon, zoom=20, size=(640, 640), scale=1, maptype="satellite",
                         api_key=API_KEY, retries=3, backoff=1.5):

    w, h = size
    url = "https://maps.googleapis.com/maps/api/staticmap"
    params = {
        "center": f"{lat},{lon}",
        "zoom": str(zoom),
        "size": f"{w}x{h}",
        "scale": str(scale),
        "maptype": maptype,
        "key": api_key,
    }
    last = None
    for attempt in range(1, retries+1):
        r = session.get(url, params=params, timeout=30)
        last = r
        if r.status_code == 200 and r.headers.get("content-type","").startswith("image/"):
            return r.content
        time.sleep(backoff ** attempt)
    raise RuntimeError(f"HTTP {last.status_code}: {last.text[:200]}")

# %%
""" descargar las imagenes satelitales
# --- Parámetros ---
STEP_METERS = 50  # 40–60 m da buen solapamiento a zoom 20
ZOOM = 20
SIZE = (640, 640)
SCALE = 1
MAPTYPE = "satellite"
OUTPUT_DIR = "/content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5"

import os, time, random, numpy as np, geopandas as gpd, pandas as pd
from shapely.geometry import LineString, MultiLineString, Point
from shapely.ops import unary_union
from pyproj import Transformer

os.makedirs(OUTPUT_DIR, exist_ok=True)

# 1) Asegurar WGS84 (lat/lon)
route_5 = route_5.to_crs(4326)

# 2) Unir toda la geometría de la Ruta 5
merged = unary_union(route_5.geometry)

# 3) Pasar a metros (EPSG:3857), muestrear cada STEP_METERS, volver a 4326
g3857 = gpd.GeoSeries([merged], crs=4326).to_crs(3857).iloc[0]

def iter_lines(g):
    if isinstance(g, LineString):
        yield g
    elif isinstance(g, MultiLineString):
        for gg in g.geoms:
            if isinstance(gg, (LineString, MultiLineString)):
                yield from iter_lines(gg)

# Muestreo ordenado con deduplicación estable
pts_3857 = []
for line in iter_lines(g3857):
    L = float(line.length)
    dists = np.arange(0, max(L, 1.0), STEP_METERS, dtype=float).tolist()
    if not dists or dists[-1] < L:
        dists.append(L)
    for d in dists:
        pts_3857.append(line.interpolate(d))

to4326 = Transformer.from_crs(3857, 4326, always_xy=True)

coords = []
seen = set()
for p in pts_3857:
    lat = to4326.transform(p.x, p.y)[1]
    lon = to4326.transform(p.x, p.y)[0]
    key = (round(lat, 6), round(lon, 6))
    if key not in seen:
        seen.add(key)
        coords.append((lat, lon))

print(f"Puntos a descargar: {len(coords)} (paso ~{STEP_METERS} m)")

# 4) Descarga con tu función test_static_maps_key
def outname(i):
    return os.path.join(OUTPUT_DIR, f"ruta5_pt_{i:05d}_z{ZOOM}.png")

# =============================
# >>> NUEVO: índice (DataFrame)
# =============================
rows = []
for i, (lat, lon) in enumerate(coords, start=1):
    path = outname(i)
    rows.append({
        "idx": i,
        "filename": f"ruta5_pt_{i:05d}_z{ZOOM}.png",
        "path": path,
        "lat": lat,
        "lon": lon,
        "exists_before": os.path.exists(path),
        "downloaded": False,   # se actualizará durante/tras la descarga
        "error": ""            # se completa si falla
    })

df = pd.DataFrame(rows).set_index("idx").sort_index()

remaining = [(i, lat, lon) for i, (lat, lon) in enumerate(coords, start=1)
             if not df.loc[i, "exists_before"]]

print(f"Total puntos: {len(coords)} | Faltan: {len(remaining)}")

errores = []
for i, lat, lon in remaining:
    try:
        img = test_static_maps_key(
            lat, lon,
            zoom=ZOOM, size=SIZE, scale=SCALE, maptype=MAPTYPE
        )
        with open(outname(i), "wb") as f:
            f.write(img)
        df.loc[i, "downloaded"] = True
        if i % 100 == 0:
            print(f"✅ Guardadas hasta el índice {i}")
    except Exception as e:
        msg = str(e)[:200]
        errores.append((i, lat, lon, msg))
        df.loc[i, "error"] = msg
        print(f"❌ {i} ({lat:.6f},{lon:.6f}) -> {msg}")
    # ~1–2 req/s con jitter para evitar 429
    time.sleep(0.25 + random.random() * 0.25)

# Marcar como descargado todo lo que efectivamente exista (por si algo preexistía)
df["downloaded"] = df["downloaded"] | (~df["exists_before"] & df["path"].apply(os.path.exists))

print("Hecho. Carpeta:", OUTPUT_DIR)
if errores:
    print(f"Quedaron {len(errores)} errores (podés reintentar solo esos).")

# =============================
# >>> NUEVO: guardar índice CSV + GeoJSON
# =============================
index_csv    = os.path.join(OUTPUT_DIR, f"ruta5_index_z{ZOOM}.csv")
index_geojson= os.path.join(OUTPUT_DIR, f"ruta5_index_z{ZOOM}.geojson")

# GeoDataFrame con puntos (WGS84)
gdf = gpd.GeoDataFrame(
    df.reset_index(),
    geometry=gpd.points_from_xy(df["lon"], df["lat"]),
    crs="EPSG:4326"
)

df.to_csv(index_csv, index=False)
# GeoJSON (compatible con QGIS/Kepler/Leaflet)
gdf.to_file(index_geojson, driver="GeoJSON")

print(f"🗂️ Índice CSV guardado en: {index_csv}")
print(f"🗺️ GeoJSON guardado en:    {index_geojson}")
# Out:
# Puntos a descargar: 13719 (paso ~50 m)
# Total puntos: 13719 | Faltan: 13719
# ✅ Guardadas hasta el índice 100
# ✅ Guardadas hasta el índice 200
# ✅ Guardadas hasta el índice 300
# ✅ Guardadas hasta el índice 400
# ✅ Guardadas hasta el índice 500
# ✅ Guardadas hasta el índice 600
# ✅ Guardadas hasta el índice 700
# ✅ Guardadas hasta el índice 800
# ✅ Guardadas hasta el índice 900
# ✅ Guardadas hasta el índice 1000
# ✅ Guardadas hasta el índice 1100
# ✅ Guardadas hasta el índice 1200
# ✅ Guardadas hasta el índice 1300
# ✅ Guardadas hasta el índice 1400
# ✅ Guardadas hasta el índice 1500
# ✅ Guardadas hasta el índice 1600
# ✅ Guardadas hasta el índice 1700
# ✅ Guardadas hasta el índice 1800
# ✅ Guardadas hasta el índice 1900
# ✅ Guardadas hasta el índice 2000
# ✅ Guardadas hasta el índice 2100
# ✅ Guardadas hasta el índice 2200
# ✅ Guardadas hasta el índice 2300
# ✅ Guardadas hasta el índice 2400
# ✅ Guardadas hasta el índice 2500
# ✅ Guardadas hasta el índice 2600
# ✅ Guardadas hasta el índice 2700
# ✅ Guardadas hasta el índice 2800
# ✅ Guardadas hasta el índice 2900
# ✅ Guardadas hasta el índice 3000
# ✅ Guardadas hasta el índice 3100
# ✅ Guardadas hasta el índice 3200
# ✅ Guardadas hasta el índice 3300
# ✅ Guardadas hasta el índice 3400
# ✅ Guardadas hasta el índice 3500
# ✅ Guardadas hasta el índice 3600
# ✅ Guardadas hasta el índice 3700
# ✅ Guardadas hasta el índice 3800
# ✅ Guardadas hasta el índice 3900
# ✅ Guardadas hasta el índice 4000
# ✅ Guardadas hasta el índice 4100
# ✅ Guardadas hasta el índice 4200
# ✅ Guardadas hasta el índice 4300
# ✅ Guardadas hasta el índice 4400
# ✅ Guardadas hasta el índice 4500
# ✅ Guardadas hasta el índice 4600
# ✅ Guardadas hasta el índice 4700
# ✅ Guardadas hasta el índice 4800
# ✅ Guardadas hasta el índice 4900
# ✅ Guardadas hasta el índice 5000
# ✅ Guardadas hasta el índice 5100
# ✅ Guardadas hasta el índice 5200
# ✅ Guardadas hasta el índice 5300
# ✅ Guardadas hasta el índice 5400
# ✅ Guardadas hasta el índice 5500
# ✅ Guardadas hasta el índice 5600
# ✅ Guardadas hasta el índice 5700
# ✅ Guardadas hasta el índice 5800
# ✅ Guardadas hasta el índice 5900
# ✅ Guardadas hasta el índice 6000
# ✅ Guardadas hasta el índice 6100
# ✅ Guardadas hasta el índice 6200
# ✅ Guardadas hasta el índice 6300
# ✅ Guardadas hasta el índice 6400
# ✅ Guardadas hasta el índice 6500
# ✅ Guardadas hasta el índice 6600
# ✅ Guardadas hasta el índice 6700
# ✅ Guardadas hasta el índice 6800
# ✅ Guardadas hasta el índice 6900
# ✅ Guardadas hasta el índice 7000
# ✅ Guardadas hasta el índice 7100
# ✅ Guardadas hasta el índice 7200
# ✅ Guardadas hasta el índice 7300
# ✅ Guardadas hasta el índice 7400
# ✅ Guardadas hasta el índice 7500
# ✅ Guardadas hasta el índice 7600
# ✅ Guardadas hasta el índice 7700
# ✅ Guardadas hasta el índice 7800
# ✅ Guardadas hasta el índice 7900
# ✅ Guardadas hasta el índice 8000
# ✅ Guardadas hasta el índice 8100
# ✅ Guardadas hasta el índice 8200
# ✅ Guardadas hasta el índice 8300
# ✅ Guardadas hasta el índice 8400
# ✅ Guardadas hasta el índice 8500
# ✅ Guardadas hasta el índice 8600
# ✅ Guardadas hasta el índice 8700
# ✅ Guardadas hasta el índice 8800
# ✅ Guardadas hasta el índice 8900
# ✅ Guardadas hasta el índice 9000
# ✅ Guardadas hasta el índice 9100
# ✅ Guardadas hasta el índice 9200
# ✅ Guardadas hasta el índice 9300
# ✅ Guardadas hasta el índice 9400
# ✅ Guardadas hasta el índice 9500
# ✅ Guardadas hasta el índice 9600
# ✅ Guardadas hasta el índice 9700
# ✅ Guardadas hasta el índice 9800
# ✅ Guardadas hasta el índice 9900
# ✅ Guardadas hasta el índice 10000
# ✅ Guardadas hasta el índice 10100
# ✅ Guardadas hasta el índice 10200
# ✅ Guardadas hasta el índice 10300
# ✅ Guardadas hasta el índice 10400
# ✅ Guardadas hasta el índice 10500
# ✅ Guardadas hasta el índice 10600
# ✅ Guardadas hasta el índice 10700
# ✅ Guardadas hasta el índice 10800
# ✅ Guardadas hasta el índice 10900
# ✅ Guardadas hasta el índice 11000
# ✅ Guardadas hasta el índice 11100
# ✅ Guardadas hasta el índice 11200
# ✅ Guardadas hasta el índice 11300
# ✅ Guardadas hasta el índice 11400
# ✅ Guardadas hasta el índice 11500
# ✅ Guardadas hasta el índice 11600
# ✅ Guardadas hasta el índice 11700
# ✅ Guardadas hasta el índice 11800
# ✅ Guardadas hasta el índice 11900
# ✅ Guardadas hasta el índice 12000
# ✅ Guardadas hasta el índice 12100
# ✅ Guardadas hasta el índice 12200
# ✅ Guardadas hasta el índice 12300
# ✅ Guardadas hasta el índice 12400
# ✅ Guardadas hasta el índice 12500
# ✅ Guardadas hasta el índice 12600
# ✅ Guardadas hasta el índice 12700
# ✅ Guardadas hasta el índice 12800
# ✅ Guardadas hasta el índice 12900
# ✅ Guardadas hasta el índice 13000
# ✅ Guardadas hasta el índice 13100
# ✅ Guardadas hasta el índice 13200
# ✅ Guardadas hasta el índice 13300
# ✅ Guardadas hasta el índice 13400
# ✅ Guardadas hasta el índice 13500
# ✅ Guardadas hasta el índice 13600
# ✅ Guardadas hasta el índice 13700
# Hecho. Carpeta: /content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5
# 🗂️ Índice CSV guardado en: /content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5/ruta5_index_z20.csv
# 🗺️ GeoJSON guardado en:    /content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5/ruta5_index_z20.geojson

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.10.5)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 1.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.1 MB/s eta 0:00:00
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.5 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 44.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 roboflow-1.2.11

# %%
# -*- coding: utf-8 -*-
# Combinar modelo de Paradas + modelo de Ruta para filtrar falsos positivos "en/encima de la ruta"
# Requiere: roboflow, shapely, pillow
# Si falta algo en Colab: !pip install shapely pillow roboflow --quiet

import os, glob, shutil
from google.colab import drive
import uuid
from roboflow import Roboflow
from PIL import Image, ImageDraw, ImageFont
from shapely.geometry import Polygon, Point, box
from shapely.ops import unary_union

# =========================
# 0) Parámetros ajustables
# =========================
CONF_PARADAS_MIN   = 55   # % mínimo para que el modelo de paradas reporte (igual que venías usando)
CONF_SEGURA_UMBRAL =  75 # % mínimo para clasificar como "segura" (entre las válidas)
ROUTE_BUFFER_PX    = 10   # px de tolerancia alrededor de la ruta para filtrar paradas "encima" de la ruta
OVERLAP_PCT        = 30   # NMS overlap (Roboflow)

# =========================
# 1) Montar Drive y carpetas
# =========================

drive.mount('/content/drive')
base_dir      = '/content/drive/MyDrive/Tesis/Datos/Imagenes_Satelitales_Ruta_5'
seguras_dir   = os.path.join(base_dir, "paradas_seguras")
noseguras_dir = os.path.join(base_dir, "paradas_no_seguras")
os.makedirs(seguras_dir, exist_ok=True)
os.makedirs(noseguras_dir, exist_ok=True)

# =========================
# 2) Cargar modelos Roboflow
# =========================
rf = Roboflow(api_key="xgcChRCI8v4AgijsjNUU")  # o usa ROBOFLOW_API_KEY

# Modelo de paradas
project_paradas = rf.project("tesis-um-n0pxr")
model_paradas   = project_paradas.version(3).model

# Modelo de ruta (detección o segmentación)
project_ruta = rf.project("identificador-de-rutas-qnmf6")
model_ruta   = project_ruta.version(2).model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''#Acá validamos el funcionamiento con un par de imágenes, modifiicamos los parámetros, y ahora vamos a corregir el orden de la función, para primero indenficificar las paradas y luego segmentar la ruta

#import uuid

IMG_PATH = '/content/drive/MyDrive/Tesis/Datos/Ruta8/ruta8_pt_00298_z20.png'

fname = os.path.basename(IMG_PATH)
print(f"\n🔍 Procesando {fname}")

# Preparamos versión RGB temporal para robustez con el SDK
rgb_path = _prep_rgb_for_rf(IMG_PATH)

# --- modelo de paradas
res_paradas = model_paradas.predict(rgb_path, confidence=CONF_PARADAS_MIN, overlap=OVERLAP_PCT).json()
preds_paradas = res_paradas.get('predictions', [])
print(f"Paradas detectadas: {len(preds_paradas)}")

if not preds_paradas:
    print("⚠️ No se detectaron paradas.")
    try:
        res_ruta = model_ruta.predict(rgb_path, confidence=30, overlap=OVERLAP_PCT).json()
    except TypeError:
        res_ruta = model_ruta.predict(rgb_path, confidence=30).json()

    preds_ruta = res_ruta.get('predictions', [])
    ruta_union = union_polygons(preds_ruta, buffer_px=ROUTE_BUFFER_PX)

    # --- filtrado
    paradas_validas, paradas_filtradas = [], []
    for p in preds_paradas:
        pt = Point(p['x'], p['y'])
        inside = (ruta_union is not None) and ruta_union.contains(pt)
        (paradas_filtradas if inside else paradas_validas).append(p)
else:
    # --- modelo de ruta (detección vs segmentación: algunos no aceptan 'overlap')
    try:
        res_ruta = model_ruta.predict(rgb_path, confidence=30, overlap=OVERLAP_PCT).json()
    except TypeError:
        res_ruta = model_ruta.predict(rgb_path, confidence=30).json()

    preds_ruta = res_ruta.get('predictions', [])
    ruta_union = union_polygons(preds_ruta, buffer_px=ROUTE_BUFFER_PX)

    # --- filtrado
    paradas_validas, paradas_filtradas = [], []
    for p in preds_paradas:
        pt = Point(p['x'], p['y'])
        inside = (ruta_union is not None) and ruta_union.contains(pt)
        (paradas_filtradas if inside else paradas_validas).append(p)

    # --- resumen
    print(f"Paradas válidas fuera de la ruta: {len(paradas_validas)}")
    print(f"Paradas filtradas (sobre ruta):   {len(paradas_filtradas)}")

    print("\n📍 Detalle de paradas válidas:")
    for p in paradas_validas:
        print(f"  - {p['class']} | conf={p['confidence']*100:.1f}% | x={p['x']:.1f}, y={p['y']:.1f}")

    print("\n🚫 Paradas filtradas por ruta:")
    for p in paradas_filtradas:
        print(f"  - {p['class']} | conf={p['confidence']*100:.1f}% | x={p['x']:.1f}, y={p['y']:.1f}")

    # --- evaluación
    if paradas_validas:
        max_conf = max(p['confidence'] for p in paradas_validas)*100
        if max_conf > CONF_SEGURA_UMBRAL:
            print(f"\n✅ Imagen clasificada como SEGURA (max_conf={max_conf:.1f}%)")
        else:
            print(f"\n⚠️ Imagen clasificada como NO SEGURA (confianza válida={max_conf:.1f}%)")
    else:
        print("\n⚠️ Imagen clasificada como NO SEGURA (todas las paradas fueron filtradas por ruta)")'''
# Out:
# '#Acá validamos el funcionamiento con un par de imágenes, modifiicamos los parámetros, y ahora vamos a corregir el orden de la función, para primero indenficificar las paradas y luego segmentar la ruta\n\n#import uuid\n\nIMG_PATH = \'/content/drive/MyDrive/Tesis/Datos/Ruta8/ruta8_pt_00298_z20.png\'\n\nfname = os.path.basename(IMG_PATH)\nprint(f"\n🔍 Procesando {fname}")\n\n# Preparamos versión RGB temporal para robustez con el SDK\nrgb_path = _prep_rgb_for_rf(IMG_PATH)\n\n# --- modelo de paradas\nres_paradas = model_paradas.predict(rgb_path, confidence=CONF_PARADAS_MIN, overlap=OVERLAP_PCT).json()\npreds_paradas = res_paradas.get(\'predictions\', [])\nprint(f"Paradas detectadas: {len(preds_paradas)}")\n\nif not preds_paradas:\n    print("⚠️ No se detectaron paradas.")\n    try:\n        res_ruta = model_ruta.predict(rgb_path, confidence=30, overlap=OVERLAP_PCT).json()\n    except TypeError:\n        res_ruta = model_ruta.predict(rgb_path, confidence=30).json()\n\n    preds_ruta = res_ruta.get(\'predictions\', [])\n    ruta_union = union_polygons(preds_ruta, buffer_px=ROUTE_BUFFER_PX)\n\n    # --- filtrado\n    paradas_validas, paradas_filtradas = [], []\n    for p in preds_paradas:\n        pt = Point(p[\'x\'], p[\'y\'])\n        inside = (ruta_union is not None) and ruta_union.contains(pt)\n        (paradas_filtradas if inside else paradas_validas).append(p)\nelse:\n    # --- modelo de ruta (detección vs segmentación: algunos no aceptan \'overlap\')\n    try:\n        res_ruta = model_ruta.predict(rgb_path, confidence=30, overlap=OVERLAP_PCT).json()\n    except TypeError:\n        res_ruta = model_ruta.predict(rgb_path, confidence=30).json()\n\n    preds_ruta = res_ruta.get(\'predictions\', [])\n    ruta_union = union_polygons(preds_ruta, buffer_px=ROUTE_BUFFER_PX)\n\n    # --- filtrado\n    paradas_validas, paradas_filtradas = [], []\n    for p in preds_paradas:\n        pt = Point(p[\'x\'], p[\'y\'])\n        inside = (ruta_union is not None) and ruta_union.contains(pt)\n        (paradas_filtradas if inside else paradas_validas).append(p)\n\n    # --- resumen\n    print(f"Paradas válidas fuera de la ruta: {len(paradas_validas)}")\n    print(f"Paradas filtradas (sobre ruta):   {len(paradas_filtradas)}")\n\n    print("\n📍 Detalle de paradas válidas:")\n    for p in paradas_validas:\n        print(f"  - {p[\'class\']} | conf={p[\'confidence\']*100:.1f}% | x={p[\'x\']:.1f}, y={p[\'y\']:.1f}")\n\n    print("\n🚫 Paradas filtradas por ruta:")\n    for p in paradas_filtradas:\n        print(f"  - {p[\'class\']} | conf={p[\'confidence\']*100:.1f}% | x={p[\'x\']:.1f}, y={p[\'y\']:.1f}")\n\n    # --- evaluación\n    if paradas_validas:\n        max_conf = max(p[\'confidence\'] for p in paradas_validas)*100\n        if max_conf > CONF_SEGURA_UMBRAL:\n            print(f"\n✅ Imagen clasificada como SEGURA (max_conf={max_conf:.1f}%)")\n        else:\n            print(f"\n⚠️ Imagen clasificada como NO SEGURA (confianza válida={max_conf:.1f}%)")\n    else:\n        print("\n⚠️ Imagen clasificada como NO SEGURA (todas las paradas fueron filtradas por ruta)")'

# %%
'''# --- BLOQUE OPCIONAL DE VISUALIZACIÓN ---
# Muestra inline la imagen con las detecciones y segmentaciones superpuestas

import matplotlib.pyplot as plt
from PIL import ImageDraw

def overlay_polygon(image, poly, outline=(255,255,255), fill_alpha=50):
    """Dibuja la ruta como región translúcida."""
    if poly is None or poly.is_empty:
        return image
    base = image.convert("RGBA")
    overlay = Image.new("RGBA", base.size, (0,0,0,0))
    draw = ImageDraw.Draw(overlay, "RGBA")

    def _draw_single(p):
        ext = [(int(x), int(y)) for x, y in p.exterior.coords]
        draw.polygon(ext, fill=(255,255,255,fill_alpha), outline=outline+(255,))
        for hole in p.interiors:
            pts = [(int(x), int(y)) for x, y in hole.coords]
            draw.polygon(pts, fill=(0,0,0,0), outline=outline+(255,))

    if poly.geom_type == "Polygon":
        _draw_single(poly)
    elif poly.geom_type == "MultiPolygon":
        for g in poly.geoms:
            _draw_single(g)

    return Image.alpha_composite(base, overlay).convert("RGB")

def draw_bbox(draw, pred, outline=(0,255,0), width=3, label=None):
    """Dibuja caja para detección."""
    x, y = pred['x'], pred['y']
    w, h = pred['width'], pred['height']
    x0, y0 = int(x - w/2), int(y - h/2)
    x1, y1 = int(x + w/2), int(y + h/2)
    draw.rectangle([x0, y0, x1, y1], outline=outline, width=width)
    if label:
        draw.text((x0+3, y0+3), label, fill=outline)

# --- construir imagen anotada ---
im = Image.open(IMG_PATH).convert("RGB")
im = overlay_polygon(im, ruta_union, outline=(255,255,255), fill_alpha=40)
draw = ImageDraw.Draw(im)

for p in paradas_validas:
    conf_pct = round(p['confidence']*100, 1)
    draw_bbox(draw, p, outline=(0,200,0), width=3, label=f"{p['class']} {conf_pct}%")

for p in paradas_filtradas:
    conf_pct = round(p['confidence']*100, 1)
    draw_bbox(draw, p, outline=(220,0,0), width=3, label=f"FILTRADA {conf_pct}%")

# --- mostrar ---
plt.figure(figsize=(8,8))
plt.imshow(im)
plt.axis("off")
plt.title("Verde: válidas  |  Rojo: filtradas  |  Blanco: ruta")
plt.show()
'''
# Out:
# '# --- BLOQUE OPCIONAL DE VISUALIZACIÓN ---\n# Muestra inline la imagen con las detecciones y segmentaciones superpuestas\n\nimport matplotlib.pyplot as plt\nfrom PIL import ImageDraw\n\ndef overlay_polygon(image, poly, outline=(255,255,255), fill_alpha=50):\n    """Dibuja la ruta como región translúcida."""\n    if poly is None or poly.is_empty:\n        return image\n    base = image.convert("RGBA")\n    overlay = Image.new("RGBA", base.size, (0,0,0,0))\n    draw = ImageDraw.Draw(overlay, "RGBA")\n\n    def _draw_single(p):\n        ext = [(int(x), int(y)) for x, y in p.exterior.coords]\n        draw.polygon(ext, fill=(255,255,255,fill_alpha), outline=outline+(255,))\n        for hole in p.interiors:\n            pts = [(int(x), int(y)) for x, y in hole.coords]\n            draw.polygon(pts, fill=(0,0,0,0), outline=outline+(255,))\n\n    if poly.geom_type == "Polygon":\n        _draw_single(poly)\n    elif poly.geom_type == "MultiPolygon":\n        for g in poly.geoms:\n            _draw_single(g)\n\n    return Image.alpha_composite(base, overlay).convert("RGB")\n\ndef draw_bbox(draw, pred, outline=(0,255,0), width=3, label=None):\n    """Dibuja caja para detección."""\n    x, y = pred[\'x\'], pred[\'y\']\n    w, h = pred[\'width\'], pred[\'height\']\n    x0, y0 = int(x - w/2), int(y - h/2)\n    x1, y1 = int(x + w/2), int(y + h/2)\n    draw.rectangle([x0, y0, x1, y1], outline=outline, width=width)\n    if label:\n        draw.text((x0+3, y0+3), label, fill=outline)\n\n# --- construir imagen anotada ---\nim = Image.open(IMG_PATH).convert("RGB")\nim = overlay_polygon(im, ruta_union, outline=(255,255,255), fill_alpha=40)\ndraw = ImageDraw.Draw(im)\n\nfor p in paradas_validas:\n    conf_pct = round(p[\'confidence\']*100, 1)\n    draw_bbox(draw, p, outline=(0,200,0), width=3, label=f"{p[\'class\']} {conf_pct}%")\n\nfor p in paradas_filtradas:\n    conf_pct = round(p[\'confidence\']*100, 1)\n    draw_bbox(draw, p, outline=(220,0,0), width=3, label=f"FILTRADA {conf_pct}%")\n\n# --- mostrar ---\nplt.figure(figsize=(8,8))\nplt.imshow(im)\nplt.axis("off")\nplt.title("Verde: válidas  |  Rojo: filtradas  |  Blanco: ruta")\nplt.show()\n'

# %%
# =========================
# 3) Utilitarios de geometría
# =========================
def pred_to_polygon(pred, buffer_px=0):
    """
    Convierte una predicción de Roboflow a un polígono de shapely.
    - Si es segmentación: usa pred['points'].
    - Si es detección: arma un rectángulo desde x,y,width,height.
    Aplica buffer (px) si se desea ensanchar.
    """
    if 'points' in pred and pred['points']:
        # Polígono (segmentación)
        pts = [(p['x'], p['y']) for p in pred['points']]
        poly = Polygon(pts)
    else:
        # Bounding box (detección)
        x, y = pred['x'], pred['y']
        w, h = pred['width'], pred['height']
        poly = box(x - w/2, y - h/2, x + w/2, y + h/2)
    if buffer_px and buffer_px > 0:
        # buffer en pixeles (en coords de imagen ya son px)
        poly = poly.buffer(buffer_px)
    return poly

def union_polygons(preds, buffer_px=0):
    """Crea la unión geométrica de las regiones detectadas/segmentadas de la ruta."""
    if not preds:
        return None
    polys = []
    for pr in preds:
        try:
            polys.append(pred_to_polygon(pr, buffer_px=buffer_px))
        except Exception:
            # Si una máscara viene malformada, la saltamos
            continue
    if not polys:
        return None
    return unary_union(polys)

def draw_bbox(draw, pred, outline=(0,255,0), width=3, label=None):
    """Dibuja una caja del pred (x,y,w,h) con un posible label."""
    x, y = pred['x'], pred['y']
    w, h = pred['width'], pred['height']
    x0, y0 = int(x - w/2), int(y - h/2)
    x1, y1 = int(x + w/2), int(y + h/2)
    draw.rectangle([x0, y0, x1, y1], outline=outline, width=width)
    if label:
        # Texto sobre el bbox
        try:
            # Colab suele no tener fuentes TTF por defecto; usamos la default.
            draw.text((x0+4, y0+4), label, fill=outline)
        except Exception:
            pass

def overlay_polygon(image, poly, outline=(255,255,255), fill_alpha=50, width=2):
    """
    Dibuja una región poligonal (o multipolígono) sobre la imagen con relleno semitransparente.
    """
    if poly is None or poly.is_empty:
        return image
    # Creamos overlay con alpha
    overlay = image.copy()
    overlay = overlay.convert("RGBA")
    tmp = Image.new("RGBA", overlay.size, (0,0,0,0))
    draw_tmp = ImageDraw.Draw(tmp, "RGBA")

    def _draw_single(p):
        try:
            exterior = [(int(x), int(y)) for x, y in p.exterior.coords]
            draw_tmp.polygon(exterior, fill=(255,255,255,fill_alpha), outline=outline+(255,))
            # holes
            for hole in p.interiors:
                hole_pts = [(int(x), int(y)) for x, y in hole.coords]
                draw_tmp.polygon(hole_pts, fill=(0,0,0,0), outline=outline+(255,))
        except Exception:
            pass

    if poly.geom_type == "Polygon":
        _draw_single(poly)
    elif poly.geom_type == "MultiPolygon":
        for p in poly.geoms:
            _draw_single(p)

    # Unir overlay
    out = Image.alpha_composite(overlay, tmp)
    return out.convert("RGB")

# %%
# =========================
# 4) Procesamiento por imagen
# =========================
imgs = glob.glob(os.path.join(base_dir, '*.png'))

# Create a temporary directory for processing
temp_dir = "/content/temp_images"
os.makedirs(temp_dir, exist_ok=True)

for img_path in imgs:
    fname = os.path.basename(img_path)

    # Convert image to RGB and save temporarily
    try:
        im = Image.open(img_path).convert("RGB")
        temp_img_path = os.path.join(temp_dir, fname)
        im.save(temp_img_path)
    except Exception as e:
        print(f"Error converting image {fname}: {e}")
        continue


    # --- 4.1) Paradas
    result_paradas = model_paradas.predict(
        temp_img_path, confidence=CONF_PARADAS_MIN, overlap=OVERLAP_PCT
    ).json()
    preds_paradas = result_paradas.get('predictions', [])

    # Si no hay paradas, guardamos la original anotada mínimamente en no seguras
    if not preds_paradas:
        # Save the original RGB converted image
        #im.save(os.path.join(noseguras_dir, fname))
        print(f"{fname}: ⚠️ no segura (sin paradas)")
        # Clean up temporary file
        os.remove(temp_img_path)
        continue

    # --- 4.2) Ruta (detección/segmentación)
    result_ruta = model_ruta.predict(
        temp_img_path, confidence=30
    ).json()
    preds_ruta = result_ruta.get('predictions', [])

    # Unión de polígonos de la ruta (buffer configurable)
    ruta_union = union_polygons(preds_ruta, buffer_px=ROUTE_BUFFER_PX)

    # --- 4.3) Filtrado de paradas: dentro de la ruta => falso positivo
    paradas_validas = []
    paradas_filtradas = []
    for p in preds_paradas:
        pt = Point(p['x'], p['y'])
        inside_route = (ruta_union is not None) and ruta_union.contains(pt)
        if inside_route:
            paradas_filtradas.append(p)
        else:
            paradas_validas.append(p)

    # --- 4.4) Anotación manual (verde=válida, rojo=filtrada), ruta en blanco translúcido
    im = Image.open(temp_img_path).convert("RGB") # Open the converted RGB image
    im = overlay_polygon(im, ruta_union, outline=(255,255,255), fill_alpha=40, width=2)
    draw = ImageDraw.Draw(im)

    # Dibujar paradas válidas (verde) y filtradas (rojo)
    for p in paradas_validas:
        conf_pct = round(p['confidence']*100, 1)
        label = f"{p['class']} {conf_pct}%"
        draw_bbox(draw, p, outline=(0,200,0), width=3, label=label)

    for p in paradas_filtradas:
        conf_pct = round(p['confidence']*100, 1)
        label = f"FILTRADA {conf_pct}%"
        draw_bbox(draw, p, outline=(220,0,0), width=3, label=label)

    # Footer con conteos
    txt = f"Válidas: {len(paradas_validas)} | Filtradas por ruta: {len(paradas_filtradas)}"
    try:
        draw.text((10, 10), txt, fill=(255,255,0))
    except Exception:
        pass

    # --- 4.5) Regla de clasificación: usa SOLO las válidas
    if paradas_validas:
        max_conf_valida = max(p['confidence'] for p in paradas_validas) * 100.0
        if max_conf_valida > CONF_SEGURA_UMBRAL:
            im.save(os.path.join(seguras_dir, fname))
            print(f"{fname}: ✅ segura | {txt} | max válida={max_conf_valida:.1f}%")
        else:
            im.save(os.path.join(noseguras_dir, fname))
            print(f"{fname}: ⚠️ no segura (baja confianza válida) | {txt} | max válida={max_conf_valida:.1f}%")
    else:
        # No quedó ninguna válida después del filtro de ruta
        im.save(os.path.join(noseguras_dir, fname))
        print(f"{fname}: ⚠️ no segura (todas filtradas por ruta) | {txt}")

    # Clean up temporary file
    os.remove(temp_img_path)

# Clean up temporary directory
os.rmdir(temp_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
# ruta5_pt_08003_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08004_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08005_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08006_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08007_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08008_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08009_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08010_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08011_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08012_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08013_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08014_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08015_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08016_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08017_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08018_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08019_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08020_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08021_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08022_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08023_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08024_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08025_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08026_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08027_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08028_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08029_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08030_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08031_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08032_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08033_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08034_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08035_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08036_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08037_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08038_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08039_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08040_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08041_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08042_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08043_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08044_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08045_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08046_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08047_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08048_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08049_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08050_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.0%
# ruta5_pt_08051_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=76.3%
# ruta5_pt_08052_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08053_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08054_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08055_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08056_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08057_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08058_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08059_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08060_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08061_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08062_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08063_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08064_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08065_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08066_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08067_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08068_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08069_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08070_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08071_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08072_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08073_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08074_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08075_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08076_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08077_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08078_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08079_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08080_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08081_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08082_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08083_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08084_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08085_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08086_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08087_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08088_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08089_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08090_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08091_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08092_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08093_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08094_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08095_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08096_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08097_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08098_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08099_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08100_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08101_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=65.3%
# ruta5_pt_08102_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08103_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08104_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08105_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08106_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08107_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08108_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08109_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08110_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08111_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08112_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08113_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08114_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08115_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08116_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08117_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08118_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08119_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08120_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08121_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08122_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08123_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08124_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08125_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08126_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08127_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08128_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08129_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08130_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08131_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08132_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08133_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08134_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08135_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08136_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08137_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08138_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08139_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08140_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08141_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08142_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08143_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08144_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08145_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08146_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08147_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08148_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08149_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08150_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08151_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08152_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08153_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08154_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=76.2%
# ruta5_pt_08155_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08156_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08157_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08158_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08159_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08160_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08161_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08162_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08163_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08164_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08165_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08166_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08167_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08168_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08169_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08170_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08171_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08172_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08173_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08174_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08175_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08176_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08177_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08178_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08179_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08180_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08181_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08182_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08183_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08184_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08185_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08186_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08187_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08188_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08189_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08190_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08191_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08192_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08193_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.7%
# ruta5_pt_08194_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=80.8%
# ruta5_pt_08195_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=61.8%
# ruta5_pt_08196_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08197_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08198_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08199_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08200_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08201_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08202_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08203_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08204_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08205_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08206_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08207_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08208_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08209_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08210_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08211_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08212_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08213_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08214_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08215_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08216_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08217_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08218_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08219_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08220_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08221_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08222_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=85.3%
# ruta5_pt_08223_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=82.8%
# ruta5_pt_08224_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=74.6%
# ruta5_pt_08225_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08226_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08227_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08228_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=84.3%
# ruta5_pt_08229_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08230_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08231_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.5%
# ruta5_pt_08232_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.7%
# ruta5_pt_08233_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08234_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08235_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08236_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08237_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08238_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08239_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08240_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08241_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08242_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08243_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08244_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08245_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08246_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08247_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08248_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08249_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08250_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08251_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=59.4%
# ruta5_pt_08252_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08253_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08254_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08255_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08256_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08257_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08258_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08259_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08260_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08261_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08262_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08263_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=65.8%
# ruta5_pt_08264_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08265_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08266_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08267_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08268_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08269_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08270_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08271_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08272_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08273_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08274_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08275_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08276_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=87.0%
# ruta5_pt_08277_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.2%
# ruta5_pt_08278_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08279_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08280_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08281_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08282_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08283_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08284_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08285_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08286_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08287_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08288_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08289_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08290_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08291_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08292_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08293_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08294_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08295_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08296_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08297_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08298_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08299_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08300_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08301_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08302_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08303_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08304_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08305_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=62.9%
# ruta5_pt_08306_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08307_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08308_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08309_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08310_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08311_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08312_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08313_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08314_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08315_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08316_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08317_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08318_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08319_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08320_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08321_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08322_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=81.3%
# ruta5_pt_08323_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08324_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08325_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08326_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08327_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08328_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08329_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08330_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08331_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08332_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08333_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08334_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08335_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08336_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08337_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08338_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08339_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08340_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08341_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08342_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08343_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08344_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.7%
# ruta5_pt_08345_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08346_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08347_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08348_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08349_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08350_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08351_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08352_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08353_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08354_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08355_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08356_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08357_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08358_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08359_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08360_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08361_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08362_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08363_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08364_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08365_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08366_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08367_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08368_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08369_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08370_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08371_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08372_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08373_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08374_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08375_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08376_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08377_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08378_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08379_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08380_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=72.6%
# ruta5_pt_08381_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08382_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08383_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08384_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08385_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08386_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08387_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08388_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08389_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08390_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08391_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08392_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08393_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08394_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08395_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08396_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08397_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08398_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08399_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08400_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08401_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08402_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08403_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08404_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08405_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08406_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08407_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08408_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08409_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08410_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08411_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08412_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08413_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08414_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08415_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08416_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08417_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08418_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08419_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08420_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08421_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08422_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08423_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08424_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08425_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.9%
# ruta5_pt_08426_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.5%
# ruta5_pt_08427_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08428_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08429_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08430_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08431_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08432_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08433_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08434_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08435_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08436_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08437_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08438_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08439_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08440_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08441_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08442_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08443_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08444_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08445_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08446_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08447_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08448_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08449_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08450_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08451_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08452_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08453_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08454_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08455_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08456_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08457_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08458_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08459_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08460_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08461_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08462_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08463_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08464_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08465_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08466_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08467_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.3%
# ruta5_pt_08468_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08469_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08470_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08471_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08472_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08473_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08474_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08475_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08476_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08477_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08478_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08479_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08480_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08481_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08482_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08483_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08484_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08485_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08486_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08487_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08488_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08489_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08490_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08491_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08492_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08493_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08494_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=64.5%
# ruta5_pt_08495_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08496_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=63.9%
# ruta5_pt_08497_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08498_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08499_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08500_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08501_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08502_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08503_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08504_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08505_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08506_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08507_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08508_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08509_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08510_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08511_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08512_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08513_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08514_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08515_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08516_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=78.0%
# ruta5_pt_08517_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08518_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08519_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08520_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08521_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=67.8%
# ruta5_pt_08522_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=85.3%
# ruta5_pt_08523_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=85.6%
# ruta5_pt_08524_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08525_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08526_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08527_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08528_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08529_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08530_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08531_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08532_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08533_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08534_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08535_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08536_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08537_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08538_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08539_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08540_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08541_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08542_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08543_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08544_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08545_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08546_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08547_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08548_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08549_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08550_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08551_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08552_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08553_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08554_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08555_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08556_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08557_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08558_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08559_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08560_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08561_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08562_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08563_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08564_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08565_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08566_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08567_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08568_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08569_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08570_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08571_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08572_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08573_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08574_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08575_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08576_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08577_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08578_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08579_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08580_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08581_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08582_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08583_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08584_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08585_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08586_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08587_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08588_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08589_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08590_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08591_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08592_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08593_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08594_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08595_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08596_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08597_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08598_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08599_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08600_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08601_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08602_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08603_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08604_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08605_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08606_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08607_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08608_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08609_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.8%
# ruta5_pt_08610_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08611_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08612_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08613_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08614_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08615_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08616_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08617_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08618_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08619_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08620_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08621_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08622_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08623_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08624_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08625_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08626_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08627_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08628_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.9%
# ruta5_pt_08629_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=83.8%
# ruta5_pt_08630_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=68.3%
# ruta5_pt_08631_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08632_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08633_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08634_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08635_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08636_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08637_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08638_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08639_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.6%
# ruta5_pt_08640_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=75.9%
# ruta5_pt_08641_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08642_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08643_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08644_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08645_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08646_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=83.4%
# ruta5_pt_08647_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=86.0%
# ruta5_pt_08648_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=86.2%
# ruta5_pt_08649_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08650_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08651_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08652_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08653_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08654_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08655_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08656_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08657_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08658_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08659_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08660_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_08661_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08662_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08663_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08664_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=76.6%
# ruta5_pt_08665_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08666_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08667_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08668_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08669_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08670_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08671_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08672_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08673_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08674_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08675_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08676_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08677_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08678_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08679_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08680_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08681_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08682_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08683_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08684_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08685_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=81.2%
# ruta5_pt_08686_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08687_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08688_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08689_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08690_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08691_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08692_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08693_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08694_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08695_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08696_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08697_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08698_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08699_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08700_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08701_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08702_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08703_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08704_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08705_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08706_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08707_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08708_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08709_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08710_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08711_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08712_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08713_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08714_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08715_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=60.6%
# ruta5_pt_08716_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08717_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08718_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08719_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08720_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08721_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08722_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_08723_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06724_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06725_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06726_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06727_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06728_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06729_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06730_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06731_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06732_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06733_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06734_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06735_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06736_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06737_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06738_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06739_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=72.0%
# ruta5_pt_06740_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06741_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=85.0%
# ruta5_pt_06742_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06743_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06744_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06745_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=80.5%
# ruta5_pt_06746_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=85.8%
# ruta5_pt_06747_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06748_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06749_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06750_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06751_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06752_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06753_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06754_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06755_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06756_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06757_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06758_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06759_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06760_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06761_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06762_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06763_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06764_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06765_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06766_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06767_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06768_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06769_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06770_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06771_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06772_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06773_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06774_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06775_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06776_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06777_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06778_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06779_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06780_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06781_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06782_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06783_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_06784_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06785_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06786_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06787_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06788_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06789_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06790_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06791_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06792_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06793_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06794_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06795_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06796_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06797_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06798_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06799_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06800_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06801_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06802_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06803_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06804_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06805_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06806_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06807_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06808_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06809_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06810_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06811_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06812_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06813_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06814_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06815_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06816_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06817_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06818_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06819_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06820_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06821_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06822_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06823_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06824_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06825_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06826_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06827_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06828_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06829_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06830_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06831_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06832_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06833_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06834_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06835_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06836_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06837_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06838_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06839_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06840_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06841_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06842_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06843_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06844_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06845_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06846_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06847_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06848_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06849_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06850_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06851_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06852_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06853_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06854_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06855_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06856_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06857_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06858_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06859_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06860_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06861_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06862_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06863_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06864_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06865_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06866_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06867_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=67.1%
# ruta5_pt_06868_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06869_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06870_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06871_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_06872_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=73.2%
# ruta5_pt_06873_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=75.1%
# ruta5_pt_06874_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=62.9%
# ruta5_pt_06875_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=72.6%
# ruta5_pt_06876_z20.png: ⚠️ no segura (sin paradas)
# ...
# ruta5_pt_02743_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02744_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02745_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02746_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02747_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02748_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02749_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02750_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02751_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02752_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02753_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02754_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02755_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02756_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02757_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02758_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02759_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02760_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02761_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02762_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02763_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02764_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02765_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02766_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02767_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02768_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02769_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02770_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02771_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02772_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02773_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02774_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02775_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02776_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02777_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02778_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02779_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02780_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02781_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02782_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02783_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02784_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=75.7%
# ruta5_pt_02785_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02786_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02787_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02788_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02789_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02790_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02791_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02792_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02793_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02794_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02795_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02796_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02797_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02798_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02799_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02800_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02801_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02802_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02803_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02804_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02805_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02806_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02807_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02808_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02809_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02810_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02811_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=57.9%
# ruta5_pt_02812_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02813_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02814_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02815_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02816_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02817_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02818_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02819_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_02820_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 3 | Filtradas por ruta: 0 | max válida=72.8%
# ruta5_pt_02821_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02822_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02823_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02824_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02825_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=81.0%
# ruta5_pt_02826_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02827_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02828_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02829_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02830_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02831_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02832_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02833_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02834_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02835_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02836_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02837_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02838_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02839_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02840_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02841_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02842_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02843_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02844_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=63.5%
# ruta5_pt_02845_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=80.9%
# ruta5_pt_02846_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02847_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02848_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02849_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02850_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02851_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02852_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02853_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02854_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02855_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02856_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02857_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02858_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02859_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02860_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02861_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 2 | Filtradas por ruta: 0 | max válida=59.2%
# ruta5_pt_02862_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02863_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.6%
# ruta5_pt_02864_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02865_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=83.0%
# ruta5_pt_02866_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=71.2%
# ruta5_pt_02867_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02868_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02869_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02870_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02871_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02872_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02873_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02874_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02875_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02876_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02877_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02878_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02879_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02880_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02881_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02882_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02883_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02884_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02885_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02886_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02887_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02888_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.0%
# ruta5_pt_02889_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=84.7%
# ruta5_pt_02890_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 1 | max válida=65.7%
# ruta5_pt_02891_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02892_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=67.2%
# ruta5_pt_02893_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.3%
# ruta5_pt_02894_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02895_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02896_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02897_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02898_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02899_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02900_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02901_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02902_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=69.3%
# ruta5_pt_02903_z20.png: ✅ segura | Válidas: 2 | Filtradas por ruta: 0 | max válida=85.1%
# ruta5_pt_02904_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=66.8%
# ruta5_pt_02905_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02906_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02907_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02908_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02909_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02910_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02911_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02912_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02913_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02914_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02915_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02916_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.6%
# ruta5_pt_02917_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=80.5%
# ruta5_pt_02918_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02919_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02920_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02921_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02922_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02923_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02924_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02925_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02926_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02927_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.6%
# ruta5_pt_02928_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=81.3%
# ruta5_pt_02929_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02930_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02931_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02932_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.7%
# ruta5_pt_02933_z20.png: ✅ segura | Válidas: 1 | Filtradas por ruta: 0 | max válida=82.0%
# ruta5_pt_02934_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02935_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02936_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02937_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02938_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02939_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02940_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02941_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02942_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02943_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02944_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=60.6%
# ruta5_pt_02945_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02946_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02947_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02948_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02949_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02950_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02951_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02952_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02953_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02954_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02955_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02956_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02957_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02958_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02959_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02960_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02961_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02962_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02963_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02964_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02965_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02966_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02967_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02968_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02969_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_02970_z20.png: ⚠️ no segura (todas filtradas por ruta) | Válidas: 0 | Filtradas por ruta: 1
# ruta5_pt_02971_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02972_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02973_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02974_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02975_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02976_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02977_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02978_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02979_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02980_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02981_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02982_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02983_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02984_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=58.3%
# ruta5_pt_02985_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02986_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02987_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02988_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02989_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02990_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02991_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02992_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02993_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02994_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02995_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02996_z20.png: ⚠️ no segura (baja confianza válida) | Válidas: 1 | Filtradas por ruta: 0 | max válida=68.1%
# ruta5_pt_02997_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02998_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_02999_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_03000_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_03001_z20.png: ⚠️ no segura (sin paradas)
# ruta5_pt_03002_z20.png: ⚠️ no segura (sin paradas)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1612757739.py in <cell line: 0>()
#      22
#      23     # --- 4.1) Paradas
# ---> 24     result_paradas = model_paradas.predict(
#      25         temp_img_path, confidence=CONF_PARADAS_MIN, overlap=OVERLAP_PCT
#      26     ).json()
#
# /usr/local/lib/python3.12/dist-packages/roboflow/models/object_detection.py in predict(self, image_path, hosted, format, classes, overlap, confidence, stroke, labels)
#     244             resp = requests.post(self.api_url)
#     245
# --> 246         resp.raise_for_status()
#     247         # Return a prediction group if JSON data
#     248         if self.format == "json":
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1024
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#    1028     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://detect.roboflow.com/tesis-um-n0pxr/3?api_key=xgcChRCI8v4AgijsjNUU&name=YOUR_IMAGE.jpg&overlap=30&confidence=55&stroke=1&labels=false&format=json

# %%
# --- 1) Montar Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- 2) Importar librerías ---
import geopandas as gpd
import folium

# --- 3) Definir la ruta al archivo KML ---
kml_path = '/content/drive/MyDrive/Tesis/Datos/Oct_5,_2025_14_03_32.kml'

# --- 4) Leer el archivo KML ---
# GeoPandas usa el driver "KML" de GDAL (ya viene en Colab)
gdf = gpd.read_file(kml_path, driver='KML')

# --- 5) Mostrar info básica ---
print("Número de puntos:", len(gdf))
print(gdf.head())

# --- 6) Crear un mapa centrado en el promedio de los puntos ---
center = [gdf.geometry.y.mean(), gdf.geometry.x.mean()]
m = folium.Map(location=center, zoom_start=8, tiles='OpenStreetMap')

# --- 7) Agregar las paradas al mapa ---
for _, row in gdf.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=str(row.get('Name', 'Parada sin nombre'))
    ).add_to(m)

# --- 8) Mostrar el mapa ---
m
# Out:
# Mounted at /content/drive
# Número de puntos: 162
#                Name                                        Description  \
# 0  Current location     Speed: 0 mph Elevation: 757 ft Accuracy: 12 ft
# 1   Stop for ~3 min  Elevation: 227 m Time from start: 00:03:34 Dis...
# 2         1 derecha  Speed: 22.57 mph Elevation: 829 ft Time from s...
# 3       2 izquierda  Speed: 25.39 mph Elevation: 813 ft Time from s...
# 4         3 derecha  Speed: 80 mph Elevation: 808 ft Time from star...
#
#                                geometry
# 0    POINT Z (-55.528 -30.90962 230.62)
# 1  POINT Z (-55.52801 -30.90962 227.44)
# 2  POINT Z (-55.54903 -30.93862 252.58)
# 3  POINT Z (-55.58999 -31.00411 248.84)
# 4   POINT Z (-55.6024 -31.04544 243.23)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_314b77f06f139c275315c1b47f2061cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_314b77f06f139c275315c1b47f2061cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_314b77f06f139c275315c1b47f2061cb = L.map(
#                 &quot;map_314b77f06f139c275315c1b47f2061cb&quot;,
#                 {
#                     center: [-33.42570997580246, -56.16432661067901],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9363469fa64f3d572dde6b63952e3cd5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9363469fa64f3d572dde6b63952e3cd5.addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#             var marker_a74a3d534eb080febc9bf883aed9c3f4 = L.marker(
#                 [-30.90961589, -55.52799677],
#                 {
# }
#             ).addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#         var popup_4a77f332b5e9d186847964b90db4daf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1e4eee393e4a49da4cf2e9ca14259a4 = $(`&lt;div id=&quot;html_d1e4eee393e4a49da4cf2e9ca14259a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Current location&lt;/div&gt;`)[0];
#                 popup_4a77f332b5e9d186847964b90db4daf6.setContent(html_d1e4eee393e4a49da4cf2e9ca14259a4);
#
#
#
#         marker_a74a3d534eb080febc9bf883aed9c3f4.bindPopup(popup_4a77f332b5e9d186847964b90db4daf6)
#         ;
#
#
#
#
#             var marker_0d7c99877d9953c602bac56a354dd386 = L.marker(
#                 [-30.90962329, -55.52800928],
#                 {
# }
#             ).addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#         var popup_e1f6ee18242e5bc75971510e7b09a107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5bcc4bddcc3d65891efea7b266b4d1 = $(`&lt;div id=&quot;html_5e5bcc4bddcc3d65891efea7b266b4d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stop for ~3 min&lt;/div&gt;`)[0];
#                 popup_e1f6ee18242e5bc75971510e7b09a107.setContent(html_5e5bcc4bddcc3d65891efea7b266b4d1);
#
#
#
#         marker_0d7c99877d9953c602bac56a354dd386.bindPopup(popup_e1f6ee18242e5bc75971510e7b09a107)
#         ;
#
#
#
#
#             var marker_338bbb11085fa63552ecc99eb66d0275 = L.marker(
#                 [-30.93861766, -55.54903055],
#                 {
# }
#             ).addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#         var popup_c8864dbaffbbadd626c92ba8c770e189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c28bbb4704df4ac99cd241798c11b541 = $(`&lt;div id=&quot;html_c28bbb4704df4ac99cd241798c11b541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 derecha&lt;/div&gt;`)[0];
#                 popup_c8864dbaffbbadd626c92ba8c770e189.setContent(html_c28bbb4704df4ac99cd241798c11b541);
#
#
#
#         marker_338bbb11085fa63552ecc99eb66d0275.bindPopup(popup_c8864dbaffbbadd626c92ba8c770e189)
#         ;
#
#
#
#
#             var marker_01faa310ec51c996853db9047bc39751 = L.marker(
#                 [-31.00410545, -55.58999164],
#                 {
# }
#             ).addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#         var popup_259ea703b382fbcb5baa0d7288fa22e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39196cda749185a7ec87e34b29ea0070 = $(`&lt;div id=&quot;html_39196cda749185a7ec87e34b29ea0070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 izquierda&lt;/div&gt;`)[0];
#                 popup_259ea703b382fbcb5baa0d7288fa22e9.setContent(html_39196cda749185a7ec87e34b29ea0070);
#
#
#
#         marker_01faa310ec51c996853db9047bc39751.bindPopup(popup_259ea703b382fbcb5baa0d7288fa22e9)
#         ;
#
#
#
#
#             var marker_1546afffae3bfc3f77486127be665bfb = L.marker(
#                 [-31.04544054, -55.60239712],
#                 {
# }
#             ).addTo(map_314b77f06f139c275315c1b47f2061cb);
#
#
#         var popup_30a52bd796845a4a1e87870b1911a6f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80ee9f64bea369328bf14d764aa28d7c = $(`&lt;div id=&quot;html_80ee9f64bea369328bf14d764aa28d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 derecha&lt;/div&gt;`)[0];
#                 popup_30a52bd796845a4a1e87870b1911a6f2.setContent(html_80ee9f64bea369328bf14d764aa28d7c

# %%
# --- Setup básico ---
from google.colab import drive
drive.mount('/content/drive')

import os, shutil, math
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from sklearn.cluster import DBSCAN

# --- Parámetros / Paths ---
BASE_DIR = "/content/drive/MyDrive/Tesis/Datos/Imagenes_Satelitales_Ruta_5"
SAFE_DIR = f"{BASE_DIR}/paradas_seguras"                          # carpeta con imágenes "seguras"
CSV_PATH = f"{BASE_DIR}/ruta5_index_z20.csv"                      # tu CSV con filename/lat/lon
OUTPUT_DIR = f"{BASE_DIR}/paradas_seguras_outputs"                # carpeta para salidas tabulares/geojson
DEDUP_IMG_DIR = f"{BASE_DIR}/paradas_seguras_dedup"               # carpeta con imágenes deduplicadas
EPS_METERS = 100.0                                                # umbral de distancia en metros para considerar duplicado
EPSG_URUGUAY_UTM21S = 32721                                       # proyección métrica

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DEDUP_IMG_DIR, exist_ok=True)

# --- 1) Leer CSV con index de imágenes (filename, lat, lon) ---
df = pd.read_csv(CSV_PATH)

# sanity check columnas mínimas
req_cols = {"filename","lat","lon"}
missing = req_cols - set(df.columns.str.lower())
if missing:
    raise ValueError(f"Faltan columnas en el CSV: {missing}. Columnas encontradas: {df.columns.tolist()}")

# Normalizar nombres de columnas por las dudas
df = df.rename(columns={"Latitude":"lat","Lat":"lat","Lon":"lon","Longitude":"lon","FileName":"filename","file_name":"filename"})

# --- 2) Listar solamente las imágenes que están en paradas_seguras ---
safe_files = [f for f in os.listdir(SAFE_DIR) ]

safe_df = df[df["filename"].isin(safe_files)].copy()

print(f"Imágenes seguras en carpeta: {len(safe_files)}")
print(f"Coincidencias filename en CSV: {len(safe_df)}")
if len(safe_df) == 0:
    raise RuntimeError("No se encontraron coincidencias entre filenames en paradas_seguras y el CSV. Revisar nombres/paths.")

# --- 3) GeoDataFrame WGS84 y proyectar a metros (EPSG:32721) ---
gdf_wgs = gpd.GeoDataFrame(
    safe_df,
    geometry=[Point(xy) for xy in zip(safe_df["lon"].values, safe_df["lat"].values)],
    crs=4326
)
gdf_m = gdf_wgs.to_crs(EPSG_URUGUAY_UTM21S)

# --- 4) DBSCAN en metros ---
coords_m = np.column_stack([gdf_m.geometry.x.values, gdf_m.geometry.y.values])
labels = DBSCAN(eps=EPS_METERS, min_samples=1, metric="euclidean").fit(coords_m).labels_
gdf_m["cluster_id"] = labels
gdf_m["cluster_size"] = gdf_m.groupby("cluster_id")["cluster_id"].transform("size")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Imágenes seguras en carpeta: 286
# Coincidencias filename en CSV: 286

# %%
# --- 5) Seleccionar un elemento representativo por cluster
representatives = gdf_m.loc[gdf_m.groupby("cluster_id").apply(
    lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
)]

# Display the representative element for each cluster
print("\nRepresentantes de cada cluster:")
display(representatives)

# Convert representatives back to WGS84 for plotting
representatives_wgs = representatives.to_crs(4326)

# --- 6) Opcional: Guardar CSV y GeoJSON de los representantes ---
representatives_csv     = os.path.join(OUTPUT_DIR, f"ruta5_paradas_representantes.csv")
representatives_geojson = os.path.join(OUTPUT_DIR, f"ruta5_paradas_representantes.geojson")

representatives_wgs.to_csv(representatives_csv, index=False)
representatives_wgs.to_file(representatives_geojson, driver="GeoJSON")

print(f"\n🗂️ Representantes CSV guardado en: {representatives_csv}")
print(f"🗺️ Representantes GeoJSON guardado en:    {representatives_geojson}")

# --- 7) Opcional: Copiar imágenes representativas a una nueva carpeta ---
for index, row in representatives_wgs.iterrows():
    src_path = row["path"]
    dest_path = os.path.join(DEDUP_IMG_DIR, row["filename"])
    if os.path.exists(src_path):
        shutil.copy(src_path, dest_path)
    else:
        print(f"Advertencia: La imagen {src_path} no fue encontrada.")

print(f"\n🖼️ Imágenes representativas copiadas a: {DEDUP_IMG_DIR}")
# Out:
# Representantes de cada cluster:
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lambda x: x.geometry.distance(x.geometry.unary_union.centroid).idxmin()
# /tmp/ipython-input-2530945813.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   representatives = gdf_m.loc[gdf_m.groupby("cluster_id").apply(
#                      filename  \
# 2783   ruta5_pt_02784_z20.png
# 2824   ruta5_pt_02825_z20.png
# 2844   ruta5_pt_02845_z20.png
# 2862   ruta5_pt_02863_z20.png
# 2864   ruta5_pt_02865_z20.png
# ...                       ...
# 13418  ruta5_pt_13419_z20.png
# 13473  ruta5_pt_13474_z20.png
# 13502  ruta5_pt_13503_z20.png
# 13701  ruta5_pt_13702_z20.png
# 13706  ruta5_pt_13707_z20.png
#
#                                                     path        lat  \
# 2783   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -32.180577
# 2824   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.832151
# 2844   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.161474
# 2862   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.922442
# 2864   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.993393
# ...                                                  ...        ...
# 13418  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.127241
# 13473  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.106562
# 13502  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.388350
# 13701  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.773589
# 13706  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.771958
#
#              lon  exists_before  downloaded  error  \
# 2783  -56.141555          False        True    NaN
# 2824  -56.299313          False        True    NaN
# 2844  -56.179938          False        True    NaN
# 2862  -56.251055          False        True    NaN
# 2864  -56.240890          False        True    NaN
# ...          ...            ...         ...    ...
# 13418 -56.460546          False        True    NaN
# 13473 -56.459721          False        True    NaN
# 13502 -56.254090          False        True    NaN
# 13701 -56.270117          False        True    NaN
# 13706 -56.269068          False        True    NaN
#
#                              geometry  cluster_id  cluster_size
# 2783   POINT (580926.698 6439225.522)           0             1
# 2824   POINT (564834.496 6256233.821)           1             1
# 2844    POINT (575588.32 6219636.055)           2             1
# 2862   POINT (569226.946 6246190.964)           3             1
# 2864   POINT (570108.327 6238316.931)           4             1
# ...                               ...         ...           ...
# 13418  POINT (550321.401 6334477.492)         162             2
# 13473  POINT (550410.169 6336769.674)         163             1
# 13502  POINT (568568.855 6194531.092)         164             1
# 13701   POINT (566786.573 6151821.99)         165             1
# 13706  POINT (566883.884 6152002.174)         166             2
#
# [167 rows x 10 columns]
# 🗂️ Representantes CSV guardado en: /content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5/ruta5_paradas_representantes.csv
# 🗺️ Representantes GeoJSON guardado en:    /content/drive/My Drive/Tesis/Datos/Imagenes_Satelitales_Ruta_5/ruta5_paradas_representantes.geojson
#
# 🖼️ Imágenes representativas copiadas a: /content/drive/MyDrive/Tesis/Datos/Imagenes_Satelitales_Ruta_5/paradas_seguras_dedup

# %%
representatives
# Out:
#                      filename  \
# 2783   ruta5_pt_02784_z20.png
# 2824   ruta5_pt_02825_z20.png
# 2844   ruta5_pt_02845_z20.png
# 2862   ruta5_pt_02863_z20.png
# 2864   ruta5_pt_02865_z20.png
# ...                       ...
# 13418  ruta5_pt_13419_z20.png
# 13473  ruta5_pt_13474_z20.png
# 13502  ruta5_pt_13503_z20.png
# 13701  ruta5_pt_13702_z20.png
# 13706  ruta5_pt_13707_z20.png
#
#                                                     path        lat  \
# 2783   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -32.180577
# 2824   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.832151
# 2844   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.161474
# 2862   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.922442
# 2864   /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.993393
# ...                                                  ...        ...
# 13418  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.127241
# 13473  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -33.106562
# 13502  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.388350
# 13701  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.773589
# 13706  /content/drive/My Drive/Tesis/Datos/Imagenes_S... -34.771958
#
#              lon  exists_before  downloaded  error  \
# 2783  -56.141555          False        True    NaN
# 2824  -56.299313          False        True    NaN
# 2844  -56.179938          False        True    NaN
# 2862  -56.251055          False        True    NaN
# 2864  -56.240890          False        True    NaN
# ...          ...            ...         ...    ...
# 13418 -56.460546          False        True    NaN
# 13473 -56.459721          False        True    NaN
# 13502 -56.254090          False        True    NaN
# 13701 -56.270117          False        True    NaN
# 13706 -56.269068          False        True    NaN
#
#                              geometry  cluster_id  cluster_size
# 2783   POINT (580926.698 6439225.522)           0             1
# 2824   POINT (564834.496 6256233.821)           1             1
# 2844    POINT (575588.32 6219636.055)           2             1
# 2862   POINT (569226.946 6246190.964)           3             1
# 2864   POINT (570108.327 6238316.931)           4             1
# ...                               ...         ...           ...
# 13418  POINT (550321.401 6334477.492)         162             2
# 13473  POINT (550410.169 6336769.674)         163             1
# 13502  POINT (568568.855 6194531.092)         164             1
# 13701   POINT (566786.573 6151821.99)         165             1
# 13706  POINT (566883.884 6152002.174)         166             2
#
# [167 rows x 10 columns]

# %%
import folium

# Create a map centered on the average location of all points
center_lat = gdf.geometry.y.mean()
center_lon = gdf.geometry.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add all original points as blue circles
for idx, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=3,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"Original Point {idx}"
    ).add_to(m)

# Add representative points as red circles
for idx, row in representatives_wgs.iterrows():
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=5,  # Slightly larger radius for representatives
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.1,
        popup=f"Representative Point {idx}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_382c54b6923f27fab83cf4d55c03d153 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_382c54b6923f27fab83cf4d55c03d153&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_382c54b6923f27fab83cf4d55c03d153 = L.map(
#                 &quot;map_382c54b6923f27fab83cf4d55c03d153&quot;,
#                 {
#                     center: [-33.42570997580246, -56.16432661067901],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc7b5019cb375de479cf6f752046fa08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc7b5019cb375de479cf6f752046fa08.addTo(map_382c54b6923f27fab83cf4d55c03d153);
#
#
#             var circle_marker_4a4cf1ca30e51ff8bbcf19b82bae1c75 = L.circleMarker(
#                 [-30.90961589, -55.52799677],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_382c54b6923f27fab83cf4d55c03d153);
#
#
#         var popup_af1104845312552758835d6b4be7eae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_609ff88e7c626926d4b62f1e783b942a = $(`&lt;div id=&quot;html_609ff88e7c626926d4b62f1e783b942a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original Point 0&lt;/div&gt;`)[0];
#                 popup_af1104845312552758835d6b4be7eae7.setContent(html_609ff88e7c626926d4b62f1e783b942a);
#
#
#
#         circle_marker_4a4cf1ca30e51ff8bbcf19b82bae1c75.bindPopup(popup_af1104845312552758835d6b4be7eae7)
#         ;
#
#
#
#
#             var circle_marker_f6ed073886dd947406463b27f5b34f05 = L.circleMarker(
#                 [-30.90962329, -55.52800928],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_382c54b6923f27fab83cf4d55c03d153);
#
#
#         var popup_5ecca3c836014e5cac73b25e3d43bdc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_463afb6c8a1699c31f93b2da897954a2 = $(`&lt;div id=&quot;html_463afb6c8a1699c31f93b2da897954a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original Point 1&lt;/div&gt;`)[0];
#                 popup_5ecca3c836014e5cac73b25e3d43bdc3.setContent(html_463afb6c8a1699c31f93b2da897954a2);
#
#
#
#         circle_marker_f6ed073886dd947406463b27f5b34f05.bindPopup(popup_5ecca3c836014e5cac73b25e3d43bdc3)
#         ;
#
#
#
#
#             var circle_marker_1bbff52d0d3e7d9b3b11c32f56bb0bff = L.circleMarker(
#                 [-30.93861766, -55.54903055],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_382c54b6923f27fab83cf4d55c03d153);
#
#
#         var popup_1b4c3bcef799c15d8a9ed2e4d681c641 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d93f07cd5930702c48881c631caef797 = $(`&lt;div id=&quot;html_d93f07cd5930702c48881c631caef797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original Point 2&lt;/div&gt;`)[0];
#                 popup_1b4c3bcef799c15d8a9ed2e4d681c641.setContent(html_d93f07cd5930702c48881c631caef797);
#
#
#
#         circle_marker_1bbff52d0d3e7d9b3b11c32f56bb0bff.bindPopup(popup_1b4c3bcef799c15d8a9ed2e4d681c641)
#         ;
#
#
#
#
#             var circle_marker_b9b

# %% [markdown]
# Representative Point 8748 - Cartel
# Representative Point 12390 - Cartel haciendo sombra

# %% [markdown]
# cruzar las paradas originales con las de nuestro modelo.
#
# arrancar la optimización de paradas para esta ruta

# %% [markdown]
# Las imagenes satelitales son anteriores a las ultimas obras de las rutas por tanto estan desactualizadas,
# lo cual lleva a incoherencias entre informacion recabada insitu y paradas detectadas por satelite.
